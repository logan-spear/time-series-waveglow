# %%
config = {'n_flows': 6, 
          'n_group': 96, 
          'n_early_every': 99, 
          'n_early_size': 8, 
          'n_layers': 4, 
          'dilation_rate': 2, 
          'dilation_list': [1,1,2,2], 
          'kernel_size': 3,
          'learning_rate': 0.001}

# %%
from untitled import run_training

# %%
run_training(small_subset=True, epochs=1, config=config)
# Out:
# 35136
# 96
# 69985
# apparently directory already exists: ./train/waveglow_ncontextchannels-96_nflows-6_ngroup-96-nearlyevery-99-nearlysize-8-nlayers-4_dilations-[1, 1, 2, 2]_nchannels_96-kernelsize-3-lr-0.00100_seed-2019
# #############
# Channels:  96
# Channels:  96
# Channels:  96
# Channels:  96
# Channels:  96
# Channels:  96
# Epoch: 1/1
# On iteration 0 with loss 31.3614
# On iteration 1 with loss 21.4211
# On iteration 2 with loss 7.9156
# On iteration 3 with loss 5.0357
# On iteration 4 with loss 2.5729
# On iteration 5 with loss 2.3386
# On iteration 6 with loss 2.2833
# On iteration 7 with loss 2.6390
# On iteration 8 with loss 2.7610
# On iteration 9 with loss 2.8215
# On iteration 10 with loss 2.8336
# On iteration 11 with loss 2.8951
# On iteration 12 with loss 2.7124
# On iteration 13 with loss 2.5757
# On iteration 14 with loss 2.6121
# On iteration 15 with loss 2.3073
# On iteration 16 with loss 2.1715
# On iteration 17 with loss 2.1042
# ...
